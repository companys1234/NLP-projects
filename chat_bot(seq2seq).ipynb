# Iteration: 252; Percent complete: 6.3%; Average loss: 3.9923
# Iteration: 253; Percent complete: 6.3%; Average loss: 4.0993
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.9463
# Iteration: 255; Percent complete: 6.4%; Average loss: 3.7595
# Iteration: 256; Percent complete: 6.4%; Average loss: 4.0488
# Iteration: 257; Percent complete: 6.4%; Average loss: 4.0834
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.0879
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.7944
# Iteration: 260; Percent complete: 6.5%; Average loss: 3.7514
# Iteration: 261; Percent complete: 6.5%; Average loss: 4.0854
# Iteration: 262; Percent complete: 6.6%; Average loss: 4.1860
# Iteration: 263; Percent complete: 6.6%; Average loss: 4.0940
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.1853
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.8071
# Iteration: 266; Percent complete: 6.7%; Average loss: 3.9993
# Iteration: 267; Percent complete: 6.7%; Average loss: 4.1859
# Iteration: 268; Percent complete: 6.7%; Average loss: 4.1280
# Iteration: 269; Percent complete: 6.7%; Average loss: 3.9033
# Iteration: 270; Percent complete: 6.8%; Average loss: 3.7809
# Iteration: 271; Percent complete: 6.8%; Average loss: 3.8009
# Iteration: 272; Percent complete: 6.8%; Average loss: 3.9979
# Iteration: 273; Percent complete: 6.8%; Average loss: 4.1881
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.7246
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.8359
# Iteration: 276; Percent complete: 6.9%; Average loss: 4.0588
# Iteration: 277; Percent complete: 6.9%; Average loss: 4.1242
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.9731
# Iteration: 279; Percent complete: 7.0%; Average loss: 3.9690
# Iteration: 280; Percent complete: 7.0%; Average loss: 3.8071
# Iteration: 281; Percent complete: 7.0%; Average loss: 4.0755
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.9132
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.0340
# Iteration: 284; Percent complete: 7.1%; Average loss: 3.9351
# Iteration: 285; Percent complete: 7.1%; Average loss: 3.9898
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.7524
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.8565
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.7161
# Iteration: 289; Percent complete: 7.2%; Average loss: 4.0717
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.0702
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.7473
# Iteration: 292; Percent complete: 7.3%; Average loss: 3.8135
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.0747
# Iteration: 294; Percent complete: 7.3%; Average loss: 4.1048
# Iteration: 295; Percent complete: 7.4%; Average loss: 3.9113
# Iteration: 296; Percent complete: 7.4%; Average loss: 4.0299
# Iteration: 297; Percent complete: 7.4%; Average loss: 4.0066
# Iteration: 298; Percent complete: 7.4%; Average loss: 4.0179
# Iteration: 299; Percent complete: 7.5%; Average loss: 4.0116
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.8896
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.8673
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.9874
# Iteration: 303; Percent complete: 7.6%; Average loss: 4.1104
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.8576
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.9725
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.9115
# Iteration: 307; Percent complete: 7.7%; Average loss: 3.8738
# Iteration: 308; Percent complete: 7.7%; Average loss: 3.8837
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.9058
# Iteration: 310; Percent complete: 7.8%; Average loss: 3.7364
# Iteration: 311; Percent complete: 7.8%; Average loss: 4.0807
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.9496
# Iteration: 313; Percent complete: 7.8%; Average loss: 4.0816
# Iteration: 314; Percent complete: 7.8%; Average loss: 3.7464
# Iteration: 315; Percent complete: 7.9%; Average loss: 3.6431
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.7655
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.9544
# Iteration: 318; Percent complete: 8.0%; Average loss: 4.0022
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.5873
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.7818
# Iteration: 321; Percent complete: 8.0%; Average loss: 4.0253
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.9401
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.7515
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.9257
# Iteration: 325; Percent complete: 8.1%; Average loss: 3.7764
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.8337
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.9898
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.7363
# Iteration: 329; Percent complete: 8.2%; Average loss: 4.0286
# Iteration: 330; Percent complete: 8.2%; Average loss: 4.1442
# Iteration: 331; Percent complete: 8.3%; Average loss: 3.8490
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.8495
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.9179
# Iteration: 334; Percent complete: 8.3%; Average loss: 3.8510
# Iteration: 335; Percent complete: 8.4%; Average loss: 3.8185
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.0125
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.7557
# Iteration: 338; Percent complete: 8.5%; Average loss: 4.1544
# Iteration: 339; Percent complete: 8.5%; Average loss: 3.9267
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.9749
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.6767
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.6302
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.7989
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.8326
# Iteration: 345; Percent complete: 8.6%; Average loss: 4.0176
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.9560
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.6044
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.8304
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.7690
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.9952
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.4743
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.9635
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.8119
# Iteration: 354; Percent complete: 8.8%; Average loss: 4.0152
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.9522
# Iteration: 356; Percent complete: 8.9%; Average loss: 4.1263
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.9611
# Iteration: 358; Percent complete: 8.9%; Average loss: 3.5974
# Iteration: 359; Percent complete: 9.0%; Average loss: 3.6048
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.5984
# Iteration: 361; Percent complete: 9.0%; Average loss: 4.0024
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.8375
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.8634
# Iteration: 364; Percent complete: 9.1%; Average loss: 4.0279
# Iteration: 365; Percent complete: 9.1%; Average loss: 4.0807
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.7036
# Iteration: 367; Percent complete: 9.2%; Average loss: 4.0089
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.6882
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.9502
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.8080
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.7836
# Iteration: 372; Percent complete: 9.3%; Average loss: 3.6935
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.9227
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.7144
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.8226
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.9192
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.9777
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.9319
# Iteration: 379; Percent complete: 9.5%; Average loss: 4.1294
# Iteration: 380; Percent complete: 9.5%; Average loss: 4.0223
# Iteration: 381; Percent complete: 9.5%; Average loss: 3.9589
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.7140
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.7390
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.8854
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.9067
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.8561
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.7267
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.6975
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.7112
# Iteration: 390; Percent complete: 9.8%; Average loss: 4.0670
# Iteration: 391; Percent complete: 9.8%; Average loss: 4.0898
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.7504
# Iteration: 393; Percent complete: 9.8%; Average loss: 4.0005
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.8853
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.8388
# Iteration: 396; Percent complete: 9.9%; Average loss: 4.0441
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.8142
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.9402
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.7341
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.6903
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.6546
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.8210
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.7706
# Iteration: 404; Percent complete: 10.1%; Average loss: 3.7763
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.6904
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.9375
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.8657
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.6315
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.7374
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.8386
# Iteration: 411; Percent complete: 10.3%; Average loss: 4.0272
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.9203
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.9676
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.8485
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.8945
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.6359
# Iteration: 417; Percent complete: 10.4%; Average loss: 4.0227
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.6911
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.7648
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.7985
# Iteration: 421; Percent complete: 10.5%; Average loss: 4.0309
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.8553
# Iteration: 423; Percent complete: 10.6%; Average loss: 3.8804
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.7590
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.6660
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.9168
# Iteration: 427; Percent complete: 10.7%; Average loss: 4.0307
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.7533
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.6621
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.6343
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.9323
# Iteration: 432; Percent complete: 10.8%; Average loss: 4.0048
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.7875
# Iteration: 434; Percent complete: 10.8%; Average loss: 3.9449
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.7932
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.8491
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.6528
# Iteration: 438; Percent complete: 10.9%; Average loss: 3.8815
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.7600
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.6580
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.5588
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.7217
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.7278
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.7887
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.6234
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.8332
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.7893
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.9896
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.6706
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.7886
# Iteration: 451; Percent complete: 11.3%; Average loss: 4.0367
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.7139
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.8008
# Iteration: 454; Percent complete: 11.3%; Average loss: 4.0272
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.7499
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.7365
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.5984
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.7772
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.9101
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.6980
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-c00d39ff97b5> in <cell line: 0>()
#      33 # Run training iterations
#      34 print("Starting Training!")
# ---> 35 trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
#      36            embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
#      37            print_every, save_every, clip, corpus_name, loadFilename)
#
# <ipython-input-35-884b1c7d04c7> in trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename)
#      20
#      21         # Run a training iteration with batch
# ---> 22         loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
#      23                      decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
#      24         print_loss += loss
#
# <ipython-input-34-78fd31f1b134> in train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip, max_length)
#      34     if use_teacher_forcing:
#      35         for t in range(max_target_len):
# ---> 36             decoder_output, decoder_hidden = decoder(
#      37                 decoder_input, decoder_hidden, encoder_outputs
#      38             )
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-32-6ea60ef8f190> in forward(self, input_step, last_hidden, encoder_outputs)
#      25         embedded = self.embedding_dropout(embedded)
#      26         # Forward through unidirectional GRU
# ---> 27         rnn_output, hidden = self.gru(embedded, last_hidden)
#      28         # Calculate attention weights from the current GRU output
#      29         attn_weights = self.attn(rnn_output, encoder_outputs)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#    1390         self.check_forward_args(input, hx, batch_sizes)
#    1391         if batch_sizes is None:
# -> 1392             result = _VF.gru(
#    1393                 input,
#    1394                 hx,
#
# KeyboardInterrupt:

# %% [markdown]
# Run Evaluation
# ==============
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hi
# Bot: you re a good . . .
# > no
# Bot: you re a good . . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-a79dd57706ac> in <cell line: 0>()
#       7
#       8 # Begin chatting (uncomment and run the following line to begin)
# ----> 9 evaluateInput(encoder, decoder, searcher, voc)
#
# <ipython-input-37-7cdfa7345e53> in evaluateInput(encoder, decoder, searcher, voc)
#      22         try:
#      23             # Get input sentence
# ---> 24             input_sentence = input('> ')
#      25             # Check if it is quit case
#      26             if input_sentence == 'q' or input_sentence == 'quit': break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
